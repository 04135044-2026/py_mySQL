# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %reload_ext autoreload


from sql_utils import create_database, create_user_table

create_database('Chapter2')
create_user_table('Chapter2')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[4], line 6
#       2
#       3
#       4 from sql_utils import create_database, create_user_table
#       5
# ----> 6 create_database('Chapter2')
#       7 create_user_table('Chapter2')
#
# File c:\Users\student\py_mySQL\Chapter2\sql_utils.py:21, in create_database(database)
#      17     sql = f"""
#      18     create database if not exists {database};
#      19             """
#      20 # 執行建立的 SQL 語句
# ---> 21 cursor.execute(sql)
#      22 # 執行查看資料庫
#      23 cursor.execute("show databases;")
#
# File c:\Users\student\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\cursors.py:154, in Cursor.execute(self, query, args)
#     139 def execute(self, query, args=None):
#     140     """Execute a query.
#     141
#     142     :param query: Query to execute.
#    (...)    152     If args is a dict, %(name)s can be used as a placeholder in the query.
#     153     """
# --> 154     while self.nextset():
#     155         pass
#     157     query = self.mogrify(query, args)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\cursors.py:104, in Cursor.nextset(self)
#     103 def nextset(self):
# --> 104     return self._nextset(False)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\cursors.py:91, in Cursor._nextset(self, unbuffered)
#      89 def _nextset(self, unbuffered=False):
#      90     """Get the next query set."""
# ---> 91     conn = self._get_db()
#      92     current_result = self._result
#      93     if current_result is None or current_result is not conn._result:
#
# File c:\Users\student\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymysql\cursors.py:73, in Cursor._get_db(self)
#      71 def _get_db(self):
#      72     if not self.connection:
# ---> 73         raise err.ProgrammingError("Cursor closed")
#      74     return self.connection
#
# ProgrammingError: Cursor closed

# %%
# %reload_ext autoreload
from sql_utils import create_user

create_user('Power',30,'Power123','123456')
